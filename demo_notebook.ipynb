# %% [markdown]
# !python --version
# !pip list

# %%
# !python --version
# !pip list
# Out:
# Python 3.13.9

# %% [markdown]
# ffrr

# %%
# !python --version
# !pip list
# Out:
# Python 3.13.9

# %%
import numpy as np
print(np.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import numpy as np
#       2 print(np.__version__)
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# !{sys.executable} -m pip install numpy
# Out:
# 'c:\Users\faizd\Desktop\dsfs-od-16\M3-Data' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
# !{sys.executable} -m pip install numpy
# Out:
# 'c:\Users\faizd\Desktop\dsfs-od-16\M3-Data' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\faizd\Desktop\dsfs-od-16\M3-Data collection and management\faiz\.venv\Scripts\python.exe

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# import numpy as np
